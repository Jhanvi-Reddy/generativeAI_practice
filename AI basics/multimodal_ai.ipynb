# %% [markdown]
# multi-modal refers to models that can process multiple types of input data - such as text images and audio toghether

# %%
import base64
image_path = "example.jpg"

with open(image_path,"rb") as image_file:
    print(base64.b64encode(image_file.read()).decode("utf-8"))
# Out:
# ...

# %%
import os
import base64
from dotenv import load_dotenv
from openai import AzureOpenAI

load_dotenv()

end_point = os.getenv("AZURE_OPENAI_GPT_4O_ENDPOINT")
api_key = os.getenv("AZURE_OPENAI_GPT_4O_API_KEY")
api_version = os.getenv("AZURE_OPENAI_GPT_4O_API_VERSION")
deployment = os.getenv("AZURE_OPENAI_GPT_4O_DEPLOYMENT_NAME ")

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=end_point,
    api_key= api_key
)

image_path = "example.jpg"  # Replace with your image file
image_base64 = base64.b64encode(open(image_path, "rb").read()).decode("utf-8")

# Send a multi-modal request
response = client.chat.completions.create(
    model="gpt-4o",
    max_tokens=1024,
    temperature=0.7,
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Describe the landmark in this picture."},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpg;base64,{image_base64}"
                    }
                }
            ]
        }
    ]
)

# Print the model's description
print(response.choices[0].message.content)
# Out:
# This image depicts a vibrant field full of sunflowers. The landmark here is not a specific structure but rather the natural beauty of the sunflower field itself. The bright yellow flowers dominate the scene, creating a stunning contrast against the greenery of the stems and leaves. In the background, the sky appears blue with soft clouds, adding to the serene and picturesque atmosphere. Sunflower fields are often admired for their aesthetic appeal and are popular spots for photography and tourism.
