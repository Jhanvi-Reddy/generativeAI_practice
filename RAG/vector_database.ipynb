# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpuNote: you may need to restart the kernel to use updated packages.
#
#   Downloading faiss_cpu-1.12.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from faiss-cpu) (23.2)
# Downloading faiss_cpu-1.12.0-cp312-cp312-win_amd64.whl (18.2 MB)
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.2 MB 8.5 MB/s eta 0:00:03
#    ------- -------------------------------- 3.4/18.2 MB 10.1 MB/s eta 0:00:02
#    ------------ --------------------------- 5.5/18.2 MB 10.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 7.6/18.2 MB 10.0 MB/s eta 0:00:02
#    --------------------- ------------------ 9.7/18.2 MB 10.1 MB/s eta 0:00:01
#    -------------------------- ------------- 12.1/18.2 MB 10.2 MB/s eta 0:00:01
#    ------------------------------- -------- 14.2/18.2 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------ --- 16.5/18.2 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 18.2/18.2 MB 10.0 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import faiss
import numpy as np
dimension = 128 #size of vector embeddings
num_vectors = 100 #number of vectors
vectors = np.random.rand(num_vectors,dimension).astype('float32')

index = faiss.IndexFlatL2(dimension)

index.add(vectors)

query_vectors = np.random.rand(1,dimension).astype('float32')
distances, indices = index.search(query_vectors,k=5) #here top 5 vectors are found

print("closest distances", distances)
print("closest vector indices", indices)
# Out:
# closest distances [[17.472698 17.618958 18.009983 18.14658  18.303402]]
# closest vector indices [[42 14 48 75 25]]

# %%
len(vectors[0])
# Out:
# 128

# %% [markdown]
# two different techniques to find similarity:
# ->semantic search
# ->cosine similarity

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.20-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.1-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (0.21.4)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (1.74.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (23.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (4.4.0)
# Requirement already satisfied: certifi in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.19.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\jhanvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\jhanvi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\jhanvi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\jhanvi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jhanvi\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\jhanvi\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.34.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\jhanvi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jhanvi\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jhanvi\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in c:\users\jhanvi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jhanvi\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jhanvi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jhanvi\appdata\roaming\python\python312\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jhanvi\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jhanvi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Downloading chromadb-1.0.20-cp39-abi3-win_amd64.whl (19.8 MB)
#    ---------------------------------------- 0.0/19.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.8 MB 1.3 MB/s eta 0:00:15
#    -- ------------------------------------- 1.0/19.8 MB 1.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 2.1/19.8 MB 3.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.4/19.8 MB 3.3 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/19.8 MB 3.2 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/19.8 MB 3.2 MB/s eta 0:00:06
#    ------- -------------------------------- 3.9/19.8 MB 2.8 MB/s eta 0:00:06
#    -------- ------------------------------- 4.2/19.8 MB 2.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.0/19.8 MB 2.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.5/19.8 MB 2.7 MB/s eta 0:00:06
#    -------------- ------------------------- 7.3/19.8 MB 3.1 MB/s eta 0:00:04
#    ------------------ --------------------- 9.2/19.8 MB 3.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 11.0/19.8 MB 4.0 MB/s eta 0:00:03
#    -------------------------- ------------- 13.1/19.8 MB 4.4 MB/s eta 0:00:02
#    ------------------------------ --------- 14.9/19.8 MB 4.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.0/19.8 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 19.1/19.8 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 19.8/19.8 MB 5.3 MB/s eta 0:00:00
# Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/1.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.5 MB/s eta 0:00:00
# Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.22.1-cp312-cp312-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.7 MB 8.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.7 MB 3.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/12.7 MB 6.0 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.7 MB 5.8 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.7 MB 5.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.7 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.7 MB 5.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.7 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.7 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 5.5 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading pybase64-1.4.2-cp312-cp312-win_amd64.whl (35 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl (292 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=12d0050df9be6b16e77f541a2b7e4f0e3da90c494d7f976d5db39bdfb2d4f8f9
#   Stored in directory: c:\users\jhanvi\appdata\local\pip\cache\wheels\d5\3d\69\8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, websockets, pyreadline3, pyproject_hooks, pybase64, opentelemetry-proto, oauthlib, mmh3, importlib-resources, httptools, bcrypt, backoff, watchfiles, uvicorn, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, humanfriendly, build, opentelemetry-semantic-conventions, kubernetes, coloredlogs, opentelemetry-sdk, onnxruntime, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 build-1.3.0 chromadb-1.0.20 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.2.10 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-33.1.0 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.22.1 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-grpc-1.36.0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 uvicorn-0.35.0 watchfiles-1.1.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb

client = chromadb.PersistentClient(path = "./chroma_data")

# %%
collection = client.get_or_create_collection(name = "rag_collection")

# %%
print(client.list_collections())
# Out:
# [Collection(name=rag_collection)]

# %%
collection.add(
    documents=[
        # Topic 1: Space Exploration
        "The Hubble Space Telescope has been orbiting Earth since 1990.",
        "NASA’s Artemis program aims to return humans to the Moon.",
        "Mars rovers like Perseverance are searching for signs of past life.",

        # Topic 2: Ancient History
        "The pyramids of Giza were built during Egypt’s Old Kingdom.",
        "The Roman Empire reached its peak under Emperor Trajan.",
        "The Indus Valley Civilization thrived around 2500 BCE.",

        # Topic 3: Modern Technology
        "Quantum computing leverages qubits to perform complex calculations.",
        "5G networks offer faster speeds and lower latency than 4G.",
        "Artificial Intelligence is transforming industries worldwide.",

        # Topic 4: Food & Cooking
        "Italian pasta comes in many shapes like penne, fusilli, and spaghetti.",
        "Sushi originated in Japan as a method of preserving fish.",
        "Sourdough bread is made using natural fermentation.",

        # Topic 5: Sports
        "The Olympics are held every four years with summer and winter editions.",
        "Football is the most popular sport globally, followed by cricket.",
        "Tennis Grand Slam tournaments include Wimbledon and the US Open."
    ],
    ids=[
        # Topic 1 IDs
        "doc1", "doc2", "doc3",
        # Topic 2 IDs
        "doc7", "doc8", "doc9",
        # Topic 3 IDs
        "doc10", "doc11", "doc12",
        # Topic 4 IDs
        "doc13", "doc14", "doc15",
        # Topic 5 IDs
        "doc16", "doc17", "doc18"
    ],
    metadatas=[
        # Topic 1 Metadata
        {"source": "space"}, {"source": "space"}, {"source": "space"},
        # Topic 2 Metadata
        {"source": "history"}, {"source": "history"}, {"source": "history"},
        # Topic 3 Metadata
        {"source": "technology"}, {"source": "technology"}, {"source": "technology"},
        # Topic 4 Metadata
        {"source": "food"}, {"source": "food"}, {"source": "food"},
        # Topic 5 Metadata
        {"source": "sports"}, {"source": "sports"}, {"source": "sports"}
    ]
)
# Out:
# C:\Users\Jhanvi\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [01:56<00:00, 712kiB/s]

# %%
results = collection.query(
    query_texts = [" sushi?"],
    n_results = 2
)

print(results)
# Out:
# {'ids': [['doc14', 'doc13']], 'embeddings': None, 'documents': [['Sushi originated in Japan as a method of preserving fish.', 'Italian pasta comes in many shapes like penne, fusilli, and spaghetti.']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'source': 'food'}, {'source': 'food'}]], 'distances': [[0.5948542952537537, 1.5998075008392334]]}

# %%
collection.update(
    ids = ["doc2"],
    documents = ["ChromaDB is often used for building AI/LLM apps with embeddings."]
)

# %%
#delete - collection.delete(ids = ["doc3"])
